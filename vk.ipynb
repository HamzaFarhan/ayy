# %%
from pathlib import Path
from typing import Literal

from valkey import Valkey

from ayy.dialog import Dialog, ModelName, create_creator
from ayy.tools2 import add_new_tools, new_task, run_tools

MODEL_NAME = ModelName.GEMINI_FLASH


def get_weather(
    day: Literal["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"], location: str
) -> str:
    "get the weather at a day in a location"
    if day == "Monday" and location.lower() == "blackpool":
        return "It's raining"
    elif day == "Tuesday" and location.lower() == "london":
        return "It's sunny"
    else:
        return "It's overcast"


def list_available_grounds(location: str) -> list[str]:
    "list all available grounds in a city"
    if location.lower() == "blackpool":
        return ["The Hawthorns", "The Den", "The New Den"]
    elif location.lower() == "london":
        return ["The Olympic Stadium", "The Emirates Stadium", "The Wembley Stadium"]
    else:
        return ["The Stadium"]


def upload_video(video_path: str) -> str:
    "save video and return the dest path"
    return video_path


# Initialize Valkey client
valkey_client = Valkey()

add_new_tools(valkey_client, new_tools=[get_weather, list_available_grounds, upload_video])
# creator = create_creator(model_name=MODEL_NAME)
# dialog = new_task(
#     valkey_client,
#     dialog=Dialog(system=Path("selector_task.txt").read_text(), model_name=MODEL_NAME),
#     task="get the weather in blackpool",
# )

# runner_dialog = run_tools(valkey_client, creator=creator, dialog=dialog)
# Out:
# /home/hamza/dev/ayy/.venv/lib/python3.12/site-packages/dill/_dill.py:422: PicklingWarning: Cannot locate reference to <class 'ayy.tools2.SelectedTool'>.
#   StockPickler.save(self, obj, save_persistent_id)
# /home/hamza/dev/ayy/.venv/lib/python3.12/site-packages/dill/_dill.py:422: PicklingWarning: Cannot pickle <class 'ayy.tools2.SelectedTool'>: ayy.tools2.SelectedTool has recursive self-references that trigger a RecursionError.
#   StockPickler.save(self, obj, save_persistent_id)
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# Cell In[2], line 42
#      39 # Initialize Valkey client
#      40 valkey_client = Valkey()
# ---> 42 add_new_tools(valkey_client, new_tools=[get_weather, list_available_grounds, upload_video])
#      43 # creator = create_creator(model_name=MODEL_NAME)
#      44 # dialog = new_task(
#      45 #     valkey_client,
#    (...)
#      49
#      50 # runner_dialog = run_tools(valkey_client, creator=creator, dialog=dialog)
#
# File ~/dev/ayy/src/ayy/tools2.py:227, in add_new_tools(valkey_client, new_tools)
#     217     tool_dict[func.__name__] = {
#     218         "info": get_function_info(func),
#     219         "func": func,  # dill will handle the function serialization
#     220     }
#     222 tool_dict["get_selected_tools"] = {
#     223     "info": get_function_info(get_selected_tools),
#     224     "func": get_selected_tools,
#     225     "type": list[create_model("SelectedTool", name=(Literal[*tool_dict.keys()], ...), __base__=Tool)],  # type: ignore
#     226 }
# --> 227 update_tool_dict(valkey_client, tool_dict)
#
# File ~/dev/ayy/src/ayy/tools2.py:49, in update_tool_dict(valkey_client, tool_dict)
#      47 def update_tool_dict(valkey_client: Valkey, tool_dict: dict):
#      48     """Update tool dictionary in Valkey store"""
# ---> 49     serialized = dill.dumps(tool_dict)
#      50     valkey_client.set("tool_dict", serialized)
#
# File ~/dev/ayy/.venv/lib/python3.12/site-packages/dill/_dill.py:288, in dumps(obj, protocol, byref, fmode, recurse, **kwds)
#     264 """
#     265 Pickle an object to a string.
#     266
#    (...)
#     285 Default values for keyword arguments can be set in :mod:`dill.settings`.
#     286 """
#     287 file = StringIO()
# --> 288 dump(obj, file, protocol, byref, fmode, recurse, **kwds)#, strictio)
#     289 return file.getvalue()
#
# File ~/dev/ayy/.venv/lib/python3.12/site-packages/dill/_dill.py:260, in dump(obj, file, protocol, byref, fmode, recurse, **kwds)
#     258 _kwds = kwds.copy()
#     259 _kwds.update(dict(byref=byref, fmode=fmode, recurse=recurse))
# --> 260 Pickler(file, protocol, **_kwds).dump(obj)
#     261 return
#
# File ~/dev/ayy/.venv/lib/python3.12/site-packages/dill/_dill.py:428, in Pickler.dump(self, obj)
#     426 def dump(self, obj): #NOTE: if settings change, need to update attributes
#     427     logger.trace_setup(self)
# --> 428     StockPickler.dump(self, obj)
#
# File /usr/lib/python3.12/pickle.py:484, in _Pickler.dump(self, obj)
#     482 if self.proto >= 4:
#     483     self.framer.start_framing()
# --> 484 self.save(obj)
#     485 self.write(STOP)
#     486 self.framer.end_framing()
#
# File ~/dev/ayy/.venv/lib/python3.12/site-packages/dill/_dill.py:422, in Pickler.save(self, obj, save_persistent_id)
#     420     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     421     raise PicklingError(msg)
# --> 422 StockPickler.save(self, obj, save_persistent_id)
#
# File /usr/lib/python3.12/pickle.py:557, in _Pickler.save(self, obj, save_persistent_id)
#     555 f = self.dispatch.get(t)
#     556 if f is not None:
# --> 557     f(self, obj)  # Call unbound method with explicit self
#     558     return
#     560 # Check private dispatch table if any, or else
#     561 # copyreg.dispatch_table
#
# File ~/dev/ayy/.venv/lib/python3.12/site-packages/dill/_dill.py:1233, in save_module_dict(pickler, obj)
#    1230     if is_dill(pickler, child=False) and pickler._session:
#    1231         # we only care about session the first pass thru
#    1232         pickler._first_pass = False
# -> 1233     StockPickler.save_dict(pickler, obj)
#    1234     logger.trace(pickler, "# D2")
#    1235 return
#
# File /usr/lib/python3.12/pickle.py:989, in _Pickler.save_dict(self, obj)
#     986     self.write(MARK + DICT)
#     988 self.memoize(obj)
# --> 989 self._batch_setitems(obj.items())
#
# File /usr/lib/python3.12/pickle.py:1013, in _Pickler._batch_setitems(self, items)
#    1011     for k, v in tmp:
#    1012         save(k)
# -> 1013         save(v)
#    1014     write(SETITEMS)
#    1015 elif n:
#
# File ~/dev/ayy/.venv/lib/python3.12/site-packages/dill/_dill.py:422, in Pickler.save(self, obj, save_persistent_id)
#     420     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     421     raise PicklingError(msg)
# --> 422 StockPickler.save(self, obj, save_persistent_id)
#
# File /usr/lib/python3.12/pickle.py:557, in _Pickler.save(self, obj, save_persistent_id)
#     555 f = self.dispatch.get(t)
#     556 if f is not None:
# --> 557     f(self, obj)  # Call unbound method with explicit self
#     558     return
#     560 # Check private dispatch table if any, or else
#     561 # copyreg.dispatch_table
#
# File ~/dev/ayy/.venv/lib/python3.12/site-packages/dill/_dill.py:1233, in save_module_dict(pickler, obj)
#    1230     if is_dill(pickler, child=False) and pickler._session:
#    1231         # we only care about session the first pass thru
#    1232         pickler._first_pass = False
# -> 1233     StockPickler.save_dict(pickler, obj)
#    1234     logger.trace(pickler, "# D2")
#    1235 return
#
# File /usr/lib/python3.12/pickle.py:989, in _Pickler.save_dict(self, obj)
#     986     self.write(MARK + DICT)
#     988 self.memoize(obj)
# --> 989 self._batch_setitems(obj.items())
#
# File /usr/lib/python3.12/pickle.py:1013, in _Pickler._batch_setitems(self, items)
#    1011     for k, v in tmp:
#    1012         save(k)
# -> 1013         save(v)
#    1014     write(SETITEMS)
#    1015 elif n:
#
# File ~/dev/ayy/.venv/lib/python3.12/site-packages/dill/_dill.py:422, in Pickler.save(self, obj, save_persistent_id)
#     420     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     421     raise PicklingError(msg)
# --> 422 StockPickler.save(self, obj, save_persistent_id)
#
# File /usr/lib/python3.12/pickle.py:600, in _Pickler.save(self, obj, save_persistent_id)
#     596     raise PicklingError("Tuple returned by %s must have "
#     597                         "two to six elements" % reduce)
#     599 # Save the reduce() output and finally memoize the object
# --> 600 self.save_reduce(obj=obj, *rv)
#
# File /usr/lib/python3.12/pickle.py:689, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     687 else:
#     688     save(func)
# --> 689     save(args)
#     690     write(REDUCE)
#     692 if obj is not None:
#     693     # If the object is already in the memo, this means it is
#     694     # recursive. In this case, throw away everything we put on the
#     695     # stack, and fetch the object back from the memo.
#
# File ~/dev/ayy/.venv/lib/python3.12/site-packages/dill/_dill.py:422, in Pickler.save(self, obj, save_persistent_id)
#     420     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     421     raise PicklingError(msg)
# --> 422 StockPickler.save(self, obj, save_persistent_id)
#
# File /usr/lib/python3.12/pickle.py:557, in _Pickler.save(self, obj, save_persistent_id)
#     555 f = self.dispatch.get(t)
#     556 if f is not None:
# --> 557     f(self, obj)  # Call unbound method with explicit self
#     558     return
#     560 # Check private dispatch table if any, or else
#     561 # copyreg.dispatch_table
#
# File /usr/lib/python3.12/pickle.py:904, in _Pickler.save_tuple(self, obj)
#     902 if n <= 3 and self.proto >= 2:
#     903     for element in obj:
# --> 904         save(element)
#     905     # Subtle.  Same as in the big comment below.
#     906     if id(obj) in memo:
#
# File ~/dev/ayy/.venv/lib/python3.12/site-packages/dill/_dill.py:422, in Pickler.save(self, obj, save_persistent_id)
#     420     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     421     raise PicklingError(msg)
# --> 422 StockPickler.save(self, obj, save_persistent_id)
#
# File /usr/lib/python3.12/pickle.py:557, in _Pickler.save(self, obj, save_persistent_id)
#     555 f = self.dispatch.get(t)
#     556 if f is not None:
# --> 557     f(self, obj)  # Call unbound method with explicit self
#     558     return
#     560 # Check private dispatch table if any, or else
#     561 # copyreg.dispatch_table
#
# File /usr/lib/python3.12/pickle.py:904, in _Pickler.save_tuple(self, obj)
#     902 if n <= 3 and self.proto >= 2:
#     903     for element in obj:
# --> 904         save(element)
#     905     # Subtle.  Same as in the big comment below.
#     906     if id(obj) in memo:
#
# File ~/dev/ayy/.venv/lib/python3.12/site-packages/dill/_dill.py:422, in Pickler.save(self, obj, save_persistent_id)
#     420     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     421     raise PicklingError(msg)
# --> 422 StockPickler.save(self, obj, save_persistent_id)
#
# File /usr/lib/python3.12/pickle.py:557, in _Pickler.save(self, obj, save_persistent_id)
#     555 f = self.dispatch.get(t)
#     556 if f is not None:
# --> 557     f(self, obj)  # Call unbound method with explicit self
#     558     return
#     560 # Check private dispatch table if any, or else
#     561 # copyreg.dispatch_table
#
# File ~/dev/ayy/.venv/lib/python3.12/site-packages/dill/_dill.py:1860, in save_type(pickler, obj, postproc_list)
#    1857     postproc_list.append((setattr, (obj, '__qualname__', qualname)))
#    1859 if not hasattr(obj, '__orig_bases__'):
# -> 1860     _save_with_postproc(pickler, (_create_type, (
#    1861         type(obj), obj.__name__, obj.__bases__, _dict
#    1862     )), obj=obj, postproc_list=postproc_list)
#    1863 else:
#    1864     # This case will always work, but might be overkill.
#    1865     _metadict = {
#    1866         'metaclass': type(obj)
#    1867     }
#
# File ~/dev/ayy/.venv/lib/python3.12/site-packages/dill/_dill.py:1114, in _save_with_postproc(pickler, reduction, is_pickler_dill, obj, postproc_list)
#    1111     pickler._postproc[id(obj)] = postproc_list
#    1113 # TODO: Use state_setter in Python 3.8 to allow for faster cPickle implementations
# -> 1114 pickler.save_reduce(*reduction, obj=obj)
#    1116 if is_pickler_dill:
#    1117     # pickler.x -= 1
#    1118     # print(pickler.x*' ', 'pop', obj, id(obj))
#    1119     postproc = pickler._postproc.pop(id(obj))
#
# File /usr/lib/python3.12/pickle.py:689, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     687 else:
#     688     save(func)
# --> 689     save(args)
#     690     write(REDUCE)
#     692 if obj is not None:
#     693     # If the object is already in the memo, this means it is
#     694     # recursive. In this case, throw away everything we put on the
#     695     # stack, and fetch the object back from the memo.
#
# File ~/dev/ayy/.venv/lib/python3.12/site-packages/dill/_dill.py:422, in Pickler.save(self, obj, save_persistent_id)
#     420     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     421     raise PicklingError(msg)
# --> 422 StockPickler.save(self, obj, save_persistent_id)
#
# File /usr/lib/python3.12/pickle.py:557, in _Pickler.save(self, obj, save_persistent_id)
#     555 f = self.dispatch.get(t)
#     556 if f is not None:
# --> 557     f(self, obj)  # Call unbound method with explicit self
#     558     return
#     560 # Check private dispatch table if any, or else
#     561 # copyreg.dispatch_table
#
# File /usr/lib/python3.12/pickle.py:919, in _Pickler.save_tuple(self, obj)
#     917 write(MARK)
#     918 for element in obj:
# --> 919     save(element)
#     921 if id(obj) in memo:
#     922     # Subtle.  d was not in memo when we entered save_tuple(), so
#     923     # the process of saving the tuple's elements must have saved
#    (...)
#     927     # could have been done in the "for element" loop instead, but
#     928     # recursive tuples are a rare thing.
#     929     get = self.get(memo[id(obj)][0])
#
# File ~/dev/ayy/.venv/lib/python3.12/site-packages/dill/_dill.py:422, in Pickler.save(self, obj, save_persistent_id)
#     420     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     421     raise PicklingError(msg)
# --> 422 StockPickler.save(self, obj, save_persistent_id)
#
# File /usr/lib/python3.12/pickle.py:557, in _Pickler.save(self, obj, save_persistent_id)
#     555 f = self.dispatch.get(t)
#     556 if f is not None:
# --> 557     f(self, obj)  # Call unbound method with explicit self
#     558     return
#     560 # Check private dispatch table if any, or else
#     561 # copyreg.dispatch_table
#
# File ~/dev/ayy/.venv/lib/python3.12/site-packages/dill/_dill.py:1233, in save_module_dict(pickler, obj)
#    1230     if is_dill(pickler, child=False) and pickler._session:
#    1231         # we only care about session the first pass thru
#    1232         pickler._first_pass = False
# -> 1233     StockPickler.save_dict(pickler, obj)
#    1234     logger.trace(pickler, "# D2")
#    1235 return
#
# File /usr/lib/python3.12/pickle.py:989, in _Pickler.save_dict(self, obj)
#     986     self.write(MARK + DICT)
#     988 self.memoize(obj)
# --> 989 self._batch_setitems(obj.items())
#
# File /usr/lib/python3.12/pickle.py:1013, in _Pickler._batch_setitems(self, items)
#    1011     for k, v in tmp:
#    1012         save(k)
# -> 1013         save(v)
#    1014     write(SETITEMS)
#    1015 elif n:
#
# File ~/dev/ayy/.venv/lib/python3.12/site-packages/dill/_dill.py:422, in Pickler.save(self, obj, save_persistent_id)
#     420     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     421     raise PicklingError(msg)
# --> 422 StockPickler.save(self, obj, save_persistent_id)
#
# File /usr/lib/python3.12/pickle.py:557, in _Pickler.save(self, obj, save_persistent_id)
#     555 f = self.dispatch.get(t)
#     556 if f is not None:
# --> 557     f(self, obj)  # Call unbound method with explicit self
#     558     return
#     560 # Check private dispatch table if any, or else
#     561 # copyreg.dispatch_table
#
# File ~/dev/ayy/.venv/lib/python3.12/site-packages/dill/_dill.py:1233, in save_module_dict(pickler, obj)
#    1230     if is_dill(pickler, child=False) and pickler._session:
#    1231         # we only care about session the first pass thru
#    1232         pickler._first_pass = False
# -> 1233     StockPickler.save_dict(pickler, obj)
#    1234     logger.trace(pickler, "# D2")
#    1235 return
#
# File /usr/lib/python3.12/pickle.py:989, in _Pickler.save_dict(self, obj)
#     986     self.write(MARK + DICT)
#     988 self.memoize(obj)
# --> 989 self._batch_setitems(obj.items())
#
# File /usr/lib/python3.12/pickle.py:1013, in _Pickler._batch_setitems(self, items)
#    1011     for k, v in tmp:
#    1012         save(k)
# -> 1013         save(v)
#    1014     write(SETITEMS)
#    1015 elif n:
#
# File ~/dev/ayy/.venv/lib/python3.12/site-packages/dill/_dill.py:422, in Pickler.save(self, obj, save_persistent_id)
#     420     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     421     raise PicklingError(msg)
# --> 422 StockPickler.save(self, obj, save_persistent_id)
#
# File /usr/lib/python3.12/pickle.py:557, in _Pickler.save(self, obj, save_persistent_id)
#     555 f = self.dispatch.get(t)
#     556 if f is not None:
# --> 557     f(self, obj)  # Call unbound method with explicit self
#     558     return
#     560 # Check private dispatch table if any, or else
#     561 # copyreg.dispatch_table
#
# File ~/dev/ayy/.venv/lib/python3.12/site-packages/dill/_dill.py:1897, in save_type(pickler, obj, postproc_list)
#    1888             warnings.warn(
#    1889                 "Cannot pickle %r: %s.%s has recursive self-references that "
#    1890                 "trigger a RecursionError." % (obj, obj.__module__, obj_name),
#    1891                 PicklingWarning,
#    1892                 stacklevel=3,
#    1893             )
#    1894        #print (obj.__dict__)
#    1895        #print ("%s\n%s" % (type(obj), obj.__name__))
#    1896        #print ("%s\n%s" % (obj.__bases__, obj.__dict__))
# -> 1897         StockPickler.save_global(pickler, obj, name=obj_name)
#    1898         logger.trace(pickler, "# T4")
#    1899 return
#
# File /usr/lib/python3.12/pickle.py:1086, in _Pickler.save_global(self, obj, name)
#    1084     obj2, parent = _getattribute(module, name)
#    1085 except (ImportError, KeyError, AttributeError):
# -> 1086     raise PicklingError(
#    1087         "Can't pickle %r: it's not found as %s.%s" %
#    1088         (obj, module_name, name)) from None
#    1089 else:
#    1090     if obj2 is not obj:
#
# PicklingError: Can't pickle <class 'ayy.tools2.SelectedTool'>: it's not found as ayy.tools2.SelectedTool
